# %% [markdown]
# # ES9ZR AI and Machine Learning for Diagnostics
#
# ## Python Lecture/Lab 5:
#
# Welcome to the lab tutorial of week 5.  The main purpose of this lab practice is to recap/revisit what we have learnt in the previous labs. Do you still have some memory for some words like Booleans, floats and strings, numpy, scipy,statistics, data preparation and Feature Extraction? It would be good if we could recall and do the tasks together.
#
# Lab 1 introduces the basics of Python and Jupyter notebooks, an interactive platform for writing and sharing Python code. Python's capabilities span automation, data visualization, machine learning, and more, but this module emphasizes ML in healthcare research. Lab 2, meanwhile, covers accessing local/online datasets and utilizing basic Python libraries in Jupyter. Lab 3 covers the basic stats applied in ML. Lab 4 focuses on data preparation and feature extraction for ML, informing you about data preprocessing, feature selection methods like PCA, and encouraging you reflecting on past analyses.
#
#
# By the end of this Lab tutorial, you should be able to:
#
# 1 Remember the actions to handle basic data types and access the Python libraries, online/offline datasets.
#
# 2 Understand and debug the Python codes by yourself to complete the tasks.
#
# 3 Reflect on the previous data analysis you have done and compare one with what you have learned today.

# %%
### Task 1 Float/Integer/Boolean/String value handling
## Task 1.1 Who am I? Please tell me what are the data types of these following variables?
print('This is the task 1.1')
Var1 = 'Hello Python'
Var2 = 1
Var3 = '1'
Var4 = True
Var5 = 1.0000

##### do you have any evidence to support your point?
# Out:
# <class 'bool'>

# %%
## Task 1.2.1 What is the 5th element(character) of Var1?
print('This is the task 1.2.1')
# Out:
# This is the task 1.2

# %%
## Task 1.2.2 Can you defuse the code bomb and output "It is safe now"?
print('This is the task 1.2.2')

CutBlueWire = True
CutRedWire = True
CutGreenWire = False
if BlueWire:
  print('A virtual electronic bomb exploded. Please try again')
elif GreenWire and RedWire and not BlueWire:
    print('It is safe now. You pass!')
else:
  print('A virtual electronic bomb exploded. Please try again')
# Out:
# A virtual electronic bomb exploded. Please try again

# %%
## Task 1.3 Please debug the following codes and print the string

print('This is the task 1.3.1')

NewString1 = "// is a slash'
print(NewString1)
# Out:
#   File "<ipython-input-15-73db1158d933>", line 5
#     NewString = "// is a slash'
#                 ^
# SyntaxError: unterminated string literal (detected at line 5)

# %%
print('This is the task 1.3.2')

NewString2 = "\This is a backslash sign\"
print(NewString2)
# Out:
#   File "<ipython-input-22-b1b7b5f7ca5d>", line 3
#     NewString2 = "\This is a backslash sign\"
#                  ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
## Task 1.4 Please output the even number that is bigger than 5 but less than 15
print('This is the task 1.4')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## Task 2.1 Import the numpy,scipy, matplotlib, pandas and Access the Iris dataset
## data = np.genfromtxt('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', delimiter=',', skip_header=0)  #pd.read_csv()
# Variable Name, Role, Type, Demographic, Description, Units, Missing Values
#
# sepal length, Feature, Continuous, cm, no
# sepal width, Feature, Continuous, cm, no
# petal length, Feature, Continuous, cm, no
# petal width, Feature, Continuous, cm, no
# class, Target, Categorical, class of iris plant: Iris Setosa, Iris Versicolour, or Iris Virginica, no


print('This is the task 2.1')
# Out:
# This is the task 2.1
# <bound method NDFrame.head of      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]>

# %%
## Task 2.2 print the 5th row of Iris dataset
## data = np.genfromtxt('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', delimiter=',', skip_header=0)  #
print('This is the task 2.2')

# %%
## Task 2.3 what is the mean value of the second colum in iris dataset?
## data = np.genfromtxt('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', delimiter=',', skip_header=0)  #
print('This is the task 2.3')

# %%
## Task 2.4 Based on scipy, is the sepal length significantly logner than the sepal width?
print('This is the task 2.4')

# %%
## Task 3 Prepare the iris dataset for ML and reduce data dimensions to 2 dimensions with PCA
### Task 3.1 check the NaN, outliners, duplicates in this dataset
print('This is the task 3.1')

# %%
### Task 3.2 Please reduce the iris dataset from 4 dimensions to 2 dimensions
print('This is the task 3.2')
